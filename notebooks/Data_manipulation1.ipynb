# %% [markdown]
# ### Data Exploration with pandas

# %%
# import required libraries
import pandas as pd
pd.set_option("display.max_rows", 13)   #to show at most 13 rows
pd.set_option("display.max_columns", 11)   #to show at most 11 columns 
pd.set_option("display.latex.repr", True)    #  is only to True set for the PDF version

# %%
# df.head() displays the first 5 lines of the DataFrame df
df = pd.read_csv('../data/titanic.csv')
df.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  ...  Parch  \
# 0                              Braund, Mr. Owen Harris    male  ...      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...      0
# 2                               Heikkinen, Miss. Laina  female  ...      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...      0
# 4                             Allen, Mr. William Henry    male  ...      0
# ..                                                 ...     ...  ...    ...
# 886                              Montvila, Rev. Juozas    male  ...      0
# 887                       Graham, Miss. Margaret Edith  female  ...      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  ...      2
# 889                              Behr, Mr. Karl Howell    male  ...      0
# 890                                Dooley, Mr. Patrick    male  ...      0
#
#                Ticket     Fare Cabin  Embarked
# 0           A/5 21171   7.2500   NaN         S
# 1            PC 17599  71.2833   C85         C
# 2    STON/O2. 3101282   7.9250   NaN         S
# 3              113803  53.1000  C123         S
# 4              373450   8.0500   NaN         S
# ..                ...      ...   ...       ...
# 886            211536  13.0000   NaN         S
# 887            112053  30.0000   B42         S
# 888        W./C. 6607  23.4500   NaN         S
# 889            111369  30.0000  C148         C
# 890            370376   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
# df.info() summarizes the content of the DataFrame df 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# df.describe() summarizes the numerical columns with some basic stats: count, min, max, mean,standard deviation etc.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# indexing:
# select  two rows
df.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  ...  Parch  \
# 0                            Braund, Mr. Owen Harris    male  ...      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...      0
#
#       Ticket     Fare Cabin  Embarked
# 0  A/5 21171   7.2500   NaN         S
# 1   PC 17599  71.2833   C85         C
#
# [2 rows x 12 columns]

# %%
# select  two columns
df[['Embarked', 'Ticket']]
# Out:
#     Embarked            Ticket
# 0          S         A/5 21171
# 1          C          PC 17599
# 2          S  STON/O2. 3101282
# 3          S            113803
# 4          S            373450
# ..       ...               ...
# 886        S            211536
# 887        S            112053
# 888        S        W./C. 6607
# 889        C            111369
# 890        Q            370376
#
# [891 rows x 2 columns]

# %%
# Select rows that fulfilled a certain conditions

# first way 
df[df['Age'] > 70]

# second way
df.query('Age> 70')
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex  ...  Parch    Ticket     Fare Cabin  Embarked
# 96   male  ...      0  PC 17754  34.6542    A5         C
# 116  male  ...      0    370369   7.7500   NaN         Q
# 493  male  ...      0  PC 17609  49.5042   NaN         C
# 630  male  ...      0     27042  30.0000   A23         S
# 851  male  ...      0    347060   7.7750   NaN         S
#
# [5 rows x 12 columns]

# %%
# Select rows that fulfilled a certain conditions, with bitwise and (&) and bitwise or (|) operators

# first way 
df[(df['Age'] == 11) | (df['SibSp'] == 5)]

# second way
df.query('(Age == 11) | (SibSp == 5)')
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 59            60         0       3   Goodwin, Master. William Frederick
# 71            72         0       3           Goodwin, Miss. Lillian Amy
# 386          387         0       3      Goodwin, Master. Sidney Leonard
# 480          481         0       3       Goodwin, Master. Harold Victor
# 542          543         0       3    Andersson, Miss. Sigrid Elisabeth
# 683          684         0       3          Goodwin, Mr. Charles Edward
# 731          732         0       3             Hassan, Mr. Houssein G N
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex  ...  Parch   Ticket      Fare    Cabin  Embarked
# 59     male  ...      2  CA 2144   46.9000      NaN         S
# 71   female  ...      2  CA 2144   46.9000      NaN         S
# 386    male  ...      2  CA 2144   46.9000      NaN         S
# 480    male  ...      2  CA 2144   46.9000      NaN         S
# 542  female  ...      2   347082   31.2750      NaN         S
# 683    male  ...      2  CA 2144   46.9000      NaN         S
# 731    male  ...      0     2699   18.7875      NaN         C
# 802    male  ...      2   113760  120.0000  B96 B98         S
#
# [8 rows x 12 columns]

# %%
# unique value of a column ( must be a series)
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# Sorting 
df.sort_values('Age', ascending = False).head()
